# %% [markdown]
# ## Implementation Stack using Array/List

# %%
class Stack:
    def __init__(self):
        self.items=[] 
    def __str__(self):
        return str(self.items)    
    # first function PUSH
    def push(self,x):
        return self.items.append(x)  #[2] #O(1)
    # second function-> pop
    def pop(self):
        if len(self.items)==0:
            return "Stack is empty BRUH!!!"
        return self.items.pop() #O(1)
    def top(self):
        if len(self.items)==0:
            return "Stack is empty BRUH!!!" 
        return self.items[-1] #O(1)
    def length(self):
        return len(self.items) #O(1)
    def is_empty(self):
        return len(self.items)==0 #O(1)

# stack object create kiya then class Stack initates an empty array
stack = Stack()
stack.push(2) # function push
stack.push(5)
stack.push(7)
stack.push(8)
 
print(f"Stack content={stack}")
print(f"popped item = {stack.pop()}")# function pop
print(f"Top element in stack ={stack.top()}")# function top
print(f"Stack content={stack}")
print(f"The length of stack={stack.length()}")# function length 
print(f"Stack is empty = {stack.is_empty()}")
# Out:
# Stack content=[2, 5, 7, 8]
# popped item = 8
# Top element in stack =7
# Stack content=[2, 5, 7]
# The length of stack=3
# Stack is empty = False

# %% [markdown]
# ## Implementation of Stack Using Queue

# %%
class Stack:
    def __init__(self):
        self.items=[]
    def __str__(self):
        return str(self.items)    
    def push(self,x):
        return self.items.append(x)
    def pop(self):
        
stack = Stack() 
stack.push(100)
stack.push(200)
stack.push(300)
print(f"Stack Content = {stack}")   
print(f"popped item = {stack.pop()}")# function pop
# Out:
# Stack Content = [100, 200, 300]
