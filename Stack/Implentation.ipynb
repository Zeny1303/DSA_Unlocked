# %% [markdown]
# ## Stack Implementation using Arrays/List

# %% [markdown]
# ##### Time Complexity = O(1)

# %%
class Stack:
    def __init__(self):
        self.items = []
    def push(self, val):
        self.items.append(val)# t.c = O(1)
    def pop(self):
        return self.items.pop()# t.c = O(1)
    def is_empty(self):
        return len(self.items) == 0 # t.c = O(1)
    def top(self):
        return self.items[-1]# t.c = O(1)
    def size(self):
        return len(self.items)# t.c = O(1)
    
    def __str__(self): #Python calls __str__ whenever you use print(obj) or str(obj)
        return f"{self.items}"  # or return ', '.join(map(str, self.items))

# driver code 
stack = Stack()
stack.push(1)
stack.push(2)
stack.push(3)
print(f"Stack content = {stack}")
# Out:
# Stack content = [1, 2, 3]

# %%
stack.pop()
# Out:
# 3

# %%
stack.top()
# Out:
# 2

# %%
stack.size()
# Out:
# 2

# %%
stack.is_empty()
# Out:
# False

# %% [markdown]
# ## Implement Stack using Queue

# %%
from collections import deque
class Stack_2():
    def __init__(self):
        self.items =deque()
    def push(self,val):
        self.items.append(val)
    def pop(self):
        return self.items.pop()     
    def size(self):
        return len(self.items)#len of items
    def top(self):
        return self.items[-1]
    def is_empty(self):
        return len(self.items) == 0 
    def __str__(self):
        return f"{self.items}"

# %%
#Driver code 
stack_2=Stack_2()
stack_2.push(30)
stack_2.push(40)
stack_2.push(50)
print(stack_2)
# Out:
# deque([30, 40, 50])

# %%
stack_2.top()
# Out:
# 50

# %%
stack_2.pop()
# Out:
# 50

# %%
stack_2.is_empty()
# Out:
# False
