# %% [markdown]
# ### Implementation of Queue using deque

# %%
from collections import deque


class Queue:
    def __init__(self):
        self.container = deque()
    def enqueue(self,val):
        return self.container.appendleft(val)
        # self.container.append(val)
        # self.container.insert(0,val)
    def dequeue(self):
        return self.container.pop()#for appendleft or insert
        #self.container.popleft()
    def is_Empty(self):
        return len(self.container) == 0
    def size(self):
        return len(self.container)
    def front(self):
        return self.container[-1]
    def __str__(self):
        return f"{self.container}"
queue = Queue()
queue.enqueue(50)
queue.enqueue(25)   
queue.enqueue(5)    
print(queue)    
queue.dequeue()           
print(queue)    
print(queue.size()) 
print(queue.is_Empty())
print(queue.front())
# Out:
# deque([5, 25, 50])
# deque([5, 25])
# 2
# False
# 25

# %% [markdown]
# ### Implementation of Queue using Arrays

# %%
class Queue_1:
    def __init__(self):
        self.items = []
    def enqueue(self,pos,val):
        self.items.insert(pos,val)
    def dequeue(self):
        return self.items.pop()
    def is_Empty(self):
        return len(self.items) == 0
    def size(self):
        return len(self.items)
    def front(self):
        return self.items[-1]  
    def __str__(self):
        return f"{self.items}"     

queue_1 = Queue_1()
queue_1.enqueue(0,50)
queue_1.enqueue(0,25)
queue_1.enqueue(0,5)
print(queue_1)
queue_1.dequeue()
print(queue_1)
print(queue_1.size())
print(queue_1.is_Empty())
print(queue_1.front())
# Out:
# [5, 25, 50]
# [5, 25]
# 2
# False
# 25
